# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
#
# -  Observed Trend 1: Temperatures decrease as we move up towards the northern hemisphere, compared to the temperatures as we move down towards southern hemisphere. <br>
# -  Observed Trend 2: The warmer the temperatures are the more humid the cities are. Looking at the two plots "latitude vs temperature" and "latitude vs humidity", the cooler the temperatues are, the humidity numbers tend to be a little lower.<br>
# -  Observed Trend 3: There is no strong relationship between latitude and wind speed. There are a few outliers but the data seems to be concentrated around 0- 20 mph.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from random import uniform

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ## Generate Cities List

# %%
column_names = ["City", "Country"]
cities_df = pd.DataFrame(columns=column_names)


# Randomly generate a list of 500 + cities. 
for x in range(1500):
    lat, lng = np.random.uniform(low=-90.000, high=90.000), np.random.uniform(low=-180.000, high=180.000)
    city = citipy.nearest_city(lat, lng)
    cities_df = cities_df.append({"City": city.city_name,"Country": city.country_code,}, ignore_index=True)

#Remove duplicate cities
cities_df = cities_df.drop_duplicates(subset='City').reset_index()
cities_df.count()
# Out:
# index      630
# City       630
# Country    630
# dtype: int64

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Api-Key
api_key = "247a814903ee011da0db7fef0e8d69c3"

#Create a df to add all the data from the API calls.
city_columns = ["City", "Country","Temperature (F)",
                "Latitude","Longitude","Humidity (%)",
                "Cloudiness (%)", "Wind Speed (mph)"]
new_cities_df = pd.DataFrame(columns=city_columns)

# Loop through the list of cities and add the data to the df.
url = "http://api.openweathermap.org/data/2.5/weather?"

row_count = 1

print("Beginning Data Retrieval")
for index, row in cities_df.iterrows():
    target_city = row["City"]
    target_url = url + "appid=" + api_key + "&units=IMPERIAL" + "&q=" + target_city.replace(" ","+")
    city_data = requests.get(target_url).json()
    if city_data["cod"] == "404":
        print("City not found, skipping...")

    else:
        new_cities_df.set_value(index, "City", city_data["name"])
        new_cities_df.set_value(index, "Country", city_data["sys"]["country"])
        new_cities_df.set_value(index, "Temperature (F)", city_data["main"]["temp"])
        new_cities_df.set_value(index, "Latitude", city_data["coord"]["lat"])
        new_cities_df.set_value(index, "Longitude", city_data["coord"]["lon"])
        new_cities_df.set_value(index, "Humidity (%)", city_data["main"]["humidity"])
        new_cities_df.set_value(index, "Cloudiness (%)", city_data["clouds"]["all"])
        new_cities_df.set_value(index, "Wind Speed (mph)", city_data["wind"]["speed"])
        
        print("------------------------")
        print("Proceesing: City # " , row_count, ' | ' , city_data["name"], city_data["sys"]["country"])
        print(target_url)
        row_count += 1
# Out:
# Beginning Data Retrieval
# ------------------------
# Proceesing: City #  1  |  Dikson RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=dikson
# ------------------------
# Proceesing: City #  2  |  Kaitangata NZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kaitangata
# C:\Users\Kabooboo\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Kabooboo\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Kabooboo\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Kabooboo\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Kabooboo\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Kabooboo\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Kabooboo\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\Kabooboo\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# City not found, skipping...
# ------------------------
# Proceesing: City #  3  |  Sao Luiz Gonzaga BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sao+luiz+gonzaga
# City not found, skipping...
# ------------------------
# Proceesing: City #  4  |  La Ronge CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=la+ronge
# ------------------------
# Proceesing: City #  5  |  Kapaa US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kapaa
# ------------------------
# Proceesing: City #  6  |  Lebu ET
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=lebu
# City not found, skipping...
# ------------------------
# Proceesing: City #  7  |  Kruisfontein ZA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kruisfontein
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  8  |  Hobart AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=hobart
# ------------------------
# Proceesing: City #  9  |  Malaya Purga RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=malaya+purga
# ------------------------
# Proceesing: City #  10  |  Camargo MX
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=camargo
# ------------------------
# Proceesing: City #  11  |  Port Elizabeth US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=port+elizabeth
# ------------------------
# Proceesing: City #  12  |  Codrington AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=codrington
# ------------------------
# Proceesing: City #  13  |  Tuktoyaktuk CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=tuktoyaktuk
# ------------------------
# Proceesing: City #  14  |  Puerto Ayora EC
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=puerto+ayora
# ------------------------
# Proceesing: City #  15  |  Ushuaia AR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ushuaia
# ------------------------
# Proceesing: City #  16  |  Hermanus ZA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=hermanus
# ------------------------
# Proceesing: City #  17  |  Camapua BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=camapua
# ------------------------
# Proceesing: City #  18  |  Namatanai PG
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=namatanai
# ------------------------
# Proceesing: City #  19  |  Rikitea PF
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=rikitea
# ------------------------
# Proceesing: City #  20  |  Archidona EC
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=archidona
# ------------------------
# Proceesing: City #  21  |  Gander CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=gander
# ------------------------
# Proceesing: City #  22  |  Albany US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=albany
# ------------------------
# Proceesing: City #  23  |  Sioux Lookout CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sioux+lookout
# ------------------------
# Proceesing: City #  24  |  Oranjemund ZA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=oranjemund
# ------------------------
# Proceesing: City #  25  |  Atuona PF
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=atuona
# ------------------------
# Proceesing: City #  26  |  Vaini IN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=vaini
# ------------------------
# Proceesing: City #  27  |  Saint-Philippe CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=saint-philippe
# ------------------------
# Proceesing: City #  28  |  Victoria BN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=victoria
# ------------------------
# Proceesing: City #  29  |  Clyde River CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=clyde+river
# ------------------------
# Proceesing: City #  30  |  Punta Arenas CL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=punta+arenas
# ------------------------
# Proceesing: City #  31  |  Coquimbo CL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=coquimbo
# ------------------------
# Proceesing: City #  32  |  Bluff AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=bluff
# ------------------------
# Proceesing: City #  33  |  Tutoia BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=tutoia
# ------------------------
# Proceesing: City #  34  |  Cape Town ZA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=cape+town
# ------------------------
# Proceesing: City #  35  |  Vostok RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=vostok
# ------------------------
# Proceesing: City #  36  |  Ponta do Sol BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ponta+do+sol
# ------------------------
# Proceesing: City #  37  |  Souillac FR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=souillac
# ------------------------
# Proceesing: City #  38  |  Kodiak US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kodiak
# ------------------------
# Proceesing: City #  39  |  Barrow AR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=barrow
# City not found, skipping...
# ------------------------
# Proceesing: City #  40  |  Kamra PK
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kamra
# ------------------------
# Proceesing: City #  41  |  Hithadhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=hithadhoo
# ------------------------
# Proceesing: City #  42  |  Saint-Joseph FR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=saint-joseph
# ------------------------
# Proceesing: City #  43  |  Mataura NZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mataura
# ------------------------
# Proceesing: City #  44  |  Avarua CK
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=avarua
# ------------------------
# Proceesing: City #  45  |  Kamenka RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kamenka
# ------------------------
# Proceesing: City #  46  |  Sorong ID
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sorong
# ------------------------
# Proceesing: City #  47  |  Mecca SA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mecca
# ------------------------
# Proceesing: City #  48  |  Bonthe SL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=bonthe
# ------------------------
# Proceesing: City #  49  |  Fortuna ES
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=fortuna
# ------------------------
# Proceesing: City #  50  |  Port Moresby PG
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=port+moresby
# ------------------------
# Proceesing: City #  51  |  Hilo US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=hilo
# ------------------------
# Proceesing: City #  52  |  Bundaberg AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=bundaberg
# ------------------------
# Proceesing: City #  53  |  Vysha RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=vysha
# ------------------------
# Proceesing: City #  54  |  Ca Mau VN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ca+mau
# ------------------------
# Proceesing: City #  55  |  Thompson CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=thompson
# ------------------------
# Proceesing: City #  56  |  Byron Bay AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=byron+bay
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  57  |  Atasu KZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=atasu
# ------------------------
# Proceesing: City #  58  |  Morondava MG
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=morondava
# City not found, skipping...
# ------------------------
# Proceesing: City #  59  |  Pemba MZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=pemba
# ------------------------
# Proceesing: City #  60  |  Valdivia CL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=valdivia
# ------------------------
# Proceesing: City #  61  |  Inirida CO
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=inirida
# City not found, skipping...
# ------------------------
# Proceesing: City #  62  |  Port Lincoln AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=port+lincoln
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  63  |  Loukhi RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=loukhi
# ------------------------
# Proceesing: City #  64  |  Mahebourg MU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mahebourg
# ------------------------
# Proceesing: City #  65  |  Bambanglipuro ID
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=bambanglipuro
# ------------------------
# Proceesing: City #  66  |  Castro CL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=castro
# ------------------------
# Proceesing: City #  67  |  Hasaki JP
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=hasaki
# ------------------------
# Proceesing: City #  68  |  Kayerkan RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kayerkan
# ------------------------
# Proceesing: City #  69  |  Busselton AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=busselton
# ------------------------
# Proceesing: City #  70  |  Talara PE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=talara
# City not found, skipping...
# ------------------------
# Proceesing: City #  71  |  Gualeguay AR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=gualeguay
# City not found, skipping...
# ------------------------
# Proceesing: City #  72  |  Santa Rosa AR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=santa+rosa
# ------------------------
# Proceesing: City #  73  |  Kutum SD
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kutum
# ------------------------
# Proceesing: City #  74  |  Cabedelo BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=cabedelo
# ------------------------
# Proceesing: City #  75  |  Tautira PF
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=tautira
# ------------------------
# Proceesing: City #  76  |  Xai-Xai MZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=xai-xai
# ------------------------
# Proceesing: City #  77  |  Guerrero Negro MX
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=guerrero+negro
# ------------------------
# Proceesing: City #  78  |  Baykit RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=baykit
# ------------------------
# Proceesing: City #  79  |  Aykhal RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=aykhal
# ------------------------
# Proceesing: City #  80  |  Slave Lake CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=slave+lake
# ------------------------
# Proceesing: City #  81  |  Tasiilaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=tasiilaq
# ------------------------
# Proceesing: City #  82  |  Haines Junction CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=haines+junction
# ------------------------
# Proceesing: City #  83  |  Margate AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=margate
# ------------------------
# Proceesing: City #  84  |  Cabo San Lucas MX
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=cabo+san+lucas
# ------------------------
# Proceesing: City #  85  |  Faya SA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=faya
# ------------------------
# Proceesing: City #  86  |  Kambam ID
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kambam
# ------------------------
# Proceesing: City #  87  |  Luanda AO
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=luanda
# ------------------------
# Proceesing: City #  88  |  Ribeira Grande PT
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ribeira+grande
# ------------------------
# Proceesing: City #  89  |  Qaanaaq GL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=qaanaaq
# ------------------------
# Proceesing: City #  90  |  Lompoc US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=lompoc
# ------------------------
# Proceesing: City #  91  |  Adrar DZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=adrar
# ------------------------
# Proceesing: City #  92  |  Pa Sang TH
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=pa+sang
# ------------------------
# Proceesing: City #  93  |  Juneau US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=juneau
# ------------------------
# Proceesing: City #  94  |  Khatanga RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=khatanga
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  95  |  Talnakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=talnakh
# ------------------------
# Proceesing: City #  96  |  Airai TL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=airai
# ------------------------
# Proceesing: City #  97  |  Leningradskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=leningradskiy
# ------------------------
# Proceesing: City #  98  |  Ternuvate UA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ternuvate
# ------------------------
# Proceesing: City #  99  |  Yellowknife CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=yellowknife
# ------------------------
# Proceesing: City #  100  |  Antofagasta CL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=antofagasta
# ------------------------
# Proceesing: City #  101  |  Zaraza VE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=zaraza
# ------------------------
# Proceesing: City #  102  |  Tibiri NE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=tibiri
# ------------------------
# Proceesing: City #  103  |  Sitka US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sitka
# ------------------------
# Proceesing: City #  104  |  Humaita AR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=humaita
# ------------------------
# Proceesing: City #  105  |  Hambantota LK
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=hambantota
# ------------------------
# Proceesing: City #  106  |  Vanimo PG
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=vanimo
# ------------------------
# Proceesing: City #  107  |  Arraial do Cabo BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=arraial+do+cabo
# ------------------------
# Proceesing: City #  108  |  Bredasdorp ZA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=bredasdorp
# ------------------------
# Proceesing: City #  109  |  Vila Franca do Campo PT
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=vila+franca+do+campo
# ------------------------
# Proceesing: City #  110  |  Bambous Virieux MU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=bambous+virieux
# ------------------------
# Proceesing: City #  111  |  Carnarvon ZA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=carnarvon
# ------------------------
# Proceesing: City #  112  |  Adre TD
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=adre
# ------------------------
# Proceesing: City #  113  |  Mar del Plata AR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mar+del+plata
# ------------------------
# Proceesing: City #  114  |  Tambun MY
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=tambun
# ------------------------
# Proceesing: City #  115  |  Marsh Harbour BS
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=marsh+harbour
# ------------------------
# Proceesing: City #  116  |  Atar MR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=atar
# ------------------------
# Proceesing: City #  117  |  Svetlaya RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=svetlaya
# ------------------------
# Proceesing: City #  118  |  Deputatskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=deputatskiy
# ------------------------
# Proceesing: City #  119  |  Mahanoro MG
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mahanoro
# ------------------------
# Proceesing: City #  120  |  Komsomolskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=komsomolskiy
# ------------------------
# Proceesing: City #  121  |  Ahuimanu US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ahuimanu
# ------------------------
# Proceesing: City #  122  |  Nemuro JP
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=nemuro
# ------------------------
# Proceesing: City #  123  |  Upernavik GL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=upernavik
# ------------------------
# Proceesing: City #  124  |  Labuhan ID
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=labuhan
# ------------------------
# Proceesing: City #  125  |  Lorengau PG
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=lorengau
# ------------------------
# Proceesing: City #  126  |  Vardo US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=vardo
# ------------------------
# Proceesing: City #  127  |  Lavrentiya RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=lavrentiya
# ------------------------
# Proceesing: City #  128  |  Salalah OM
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=salalah
# ------------------------
# Proceesing: City #  129  |  Pevek RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=pevek
# ------------------------
# Proceesing: City #  130  |  Ilulissat GL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ilulissat
# ------------------------
# Proceesing: City #  131  |  Ormara PK
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ormara
# ------------------------
# Proceesing: City #  132  |  Irtyshskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=irtyshskiy
# ------------------------
# Proceesing: City #  133  |  East London ZA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=east+london
# ------------------------
# Proceesing: City #  134  |  Baghmara IN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=baghmara
# ------------------------
# Proceesing: City #  135  |  Ambon FR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ambon
# ------------------------
# Proceesing: City #  136  |  New Norfolk AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=new+norfolk
# ------------------------
# Proceesing: City #  137  |  Broome GB
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=broome
# ------------------------
# Proceesing: City #  138  |  Sharjah AE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sharjah
# ------------------------
# Proceesing: City #  139  |  Santa Cruz US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=santa+cruz
# ------------------------
# Proceesing: City #  140  |  Anapskaya RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=anapskaya
# ------------------------
# Proceesing: City #  141  |  Pangkalanbuun ID
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=pangkalanbuun
# ------------------------
# Proceesing: City #  142  |  Ternate PH
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ternate
# ------------------------
# Proceesing: City #  143  |  Sterling US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sterling
# ------------------------
# Proceesing: City #  144  |  Coihaique CL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=coihaique
# ------------------------
# Proceesing: City #  145  |  Buchanan LR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=buchanan
# ------------------------
# Proceesing: City #  146  |  Saskylakh RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=saskylakh
# ------------------------
# Proceesing: City #  147  |  Burns Lake CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=burns+lake
# ------------------------
# Proceesing: City #  148  |  Te Anau NZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=te+anau
# ------------------------
# Proceesing: City #  149  |  Rome IT
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=roma
# ------------------------
# Proceesing: City #  150  |  Lithakia GR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=lithakia
# ------------------------
# Proceesing: City #  151  |  Ostrovnoy RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ostrovnoy
# City not found, skipping...
# City not found, skipping...
# ------------------------
# Proceesing: City #  152  |  Anse-Bertrand GP
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=anse-bertrand
# ------------------------
# Proceesing: City #  153  |  Yuncheng CN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=yuncheng
# ------------------------
# Proceesing: City #  154  |  Klaksvik FO
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=klaksvik
# ------------------------
# Proceesing: City #  155  |  Fort Wellington GY
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=fort+wellington
# ------------------------
# Proceesing: City #  156  |  Jamestown AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=jamestown
# ------------------------
# Proceesing: City #  157  |  Tolga DZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=tolga
# ------------------------
# Proceesing: City #  158  |  San Rafael AR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=san+rafael
# ------------------------
# Proceesing: City #  159  |  Kavaratti IN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kavaratti
# ------------------------
# Proceesing: City #  160  |  Longyearbyen NO
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=longyearbyen
# ------------------------
# Proceesing: City #  161  |  Tolaga Bay NZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=tolaga+bay
# ------------------------
# Proceesing: City #  162  |  Nanzhang CN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=nanzhang
# ------------------------
# Proceesing: City #  163  |  Dicabisagan PH
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=dicabisagan
# ------------------------
# Proceesing: City #  164  |  Mandera ET
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mandera
# ------------------------
# Proceesing: City #  165  |  Provideniya RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=provideniya
# ------------------------
# Proceesing: City #  166  |  Kletskaya RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kletskaya
# ------------------------
# Proceesing: City #  167  |  Poltavka RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=poltavka
# ------------------------
# Proceesing: City #  168  |  Iqaluit CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=iqaluit
# ------------------------
# Proceesing: City #  169  |  Kerman IR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kerman
# ------------------------
# Proceesing: City #  170  |  Tuatapere NZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=tuatapere
# ------------------------
# Proceesing: City #  171  |  Ampanihy MG
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ampanihy
# ------------------------
# Proceesing: City #  172  |  Chuy UY
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=chuy
# ------------------------
# Proceesing: City #  173  |  Hirara JP
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=hirara
# ------------------------
# Proceesing: City #  174  |  Norman Wells CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=norman+wells
# ------------------------
# Proceesing: City #  175  |  Teshie GH
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=teshie
# ------------------------
# Proceesing: City #  176  |  Iskateley RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=iskateley
# ------------------------
# Proceesing: City #  177  |  Georgetown GY
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=georgetown
# ------------------------
# Proceesing: City #  178  |  Neryungri RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=neryungri
# ------------------------
# Proceesing: City #  179  |  Rocha UY
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=rocha
# ------------------------
# Proceesing: City #  180  |  Nikolskoye RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=nikolskoye
# ------------------------
# Proceesing: City #  181  |  Yaring TH
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=yaring
# ------------------------
# Proceesing: City #  182  |  Butaritari KI
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=butaritari
# City not found, skipping...
# ------------------------
# Proceesing: City #  183  |  Brigantine US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=brigantine
# ------------------------
# Proceesing: City #  184  |  Normandin CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=normandin
# ------------------------
# Proceesing: City #  185  |  Tvedestrand NO
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=tvedestrand
# ------------------------
# Proceesing: City #  186  |  Okhotsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=okhotsk
# ------------------------
# Proceesing: City #  187  |  Tabuk PH
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=tabuk
# ------------------------
# Proceesing: City #  188  |  Kahului US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kahului
# ------------------------
# Proceesing: City #  189  |  Saldanha PT
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=saldanha
# ------------------------
# Proceesing: City #  190  |  Saint George GR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=saint+george
# ------------------------
# Proceesing: City #  191  |  Namtsy RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=namtsy
# ------------------------
# Proceesing: City #  192  |  Gat SN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=gat
# ------------------------
# Proceesing: City #  193  |  Diban SY
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=diban
# ------------------------
# Proceesing: City #  194  |  Talaya RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=talaya
# ------------------------
# Proceesing: City #  195  |  Temiscaming CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=temiscaming
# ------------------------
# Proceesing: City #  196  |  Ocos GT
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ocos
# ------------------------
# Proceesing: City #  197  |  Ozinki RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ozinki
# ------------------------
# Proceesing: City #  198  |  San Quintin PH
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=san+quintin
# ------------------------
# Proceesing: City #  199  |  Zhigansk RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=zhigansk
# ------------------------
# Proceesing: City #  200  |  Faanui PF
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=faanui
# ------------------------
# Proceesing: City #  201  |  Champerico MX
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=champerico
# ------------------------
# Proceesing: City #  202  |  Teguise ES
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=teguise
# ------------------------
# Proceesing: City #  203  |  Ylivieska FI
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ylivieska
# ------------------------
# Proceesing: City #  204  |  Grand Gaube MU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=grand+gaube
# City not found, skipping...
# ------------------------
# Proceesing: City #  205  |  Nola CF
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=nola
# City not found, skipping...
# ------------------------
# Proceesing: City #  206  |  Lasa CY
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=lasa
# ------------------------
# Proceesing: City #  207  |  Aklavik CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=aklavik
# ------------------------
# Proceesing: City #  208  |  Jiazi CN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=jiazi
# ------------------------
# Proceesing: City #  209  |  Esperance TT
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=esperance
# ------------------------
# Proceesing: City #  210  |  Synya RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=synya
# ------------------------
# Proceesing: City #  211  |  Lerwick GB
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=lerwick
# ------------------------
# Proceesing: City #  212  |  Terrace Bay CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=terrace+bay
# ------------------------
# Proceesing: City #  213  |  Vanderhoof CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=vanderhoof
# ------------------------
# Proceesing: City #  214  |  Dandong CN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=dandong
# ------------------------
# Proceesing: City #  215  |  Salym RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=salym
# City not found, skipping...
# ------------------------
# Proceesing: City #  216  |  Priargunsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=priargunsk
# ------------------------
# Proceesing: City #  217  |  Torremolinos ES
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=torremolinos
# ------------------------
# Proceesing: City #  218  |  Sinnamary GF
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sinnamary
# ------------------------
# Proceesing: City #  219  |  Skelleftea SE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=skelleftea
# ------------------------
# Proceesing: City #  220  |  Solnechnyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=solnechnyy
# City not found, skipping...
# ------------------------
# Proceesing: City #  221  |  Priiskovyy RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=priiskovyy
# ------------------------
# Proceesing: City #  222  |  Pangoa PE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=pangoa
# ------------------------
# Proceesing: City #  223  |  Kurchum KZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kurchum
# ------------------------
# Proceesing: City #  224  |  Severo-Kurilsk RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=severo-kurilsk
# ------------------------
# Proceesing: City #  225  |  Nome US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=nome
# ------------------------
# Proceesing: City #  226  |  Ngorongoro TZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ngorongoro
# ------------------------
# Proceesing: City #  227  |  Beringovskiy RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=beringovskiy
# ------------------------
# Proceesing: City #  228  |  Karlskoga SE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=karlskoga
# City not found, skipping...
# ------------------------
# Proceesing: City #  229  |  Lata IN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=lata
# ------------------------
# Proceesing: City #  230  |  Pisco PE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=pisco
# ------------------------
# Proceesing: City #  231  |  Mount Isa AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mount+isa
# City not found, skipping...
# ------------------------
# Proceesing: City #  232  |  Sabalgarh IN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sabalgarh
# ------------------------
# Proceesing: City #  233  |  Sao Jose da Coroa Grande BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sao+jose+da+coroa+grande
# City not found, skipping...
# ------------------------
# Proceesing: City #  234  |  Leirvik NO
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=leirvik
# ------------------------
# Proceesing: City #  235  |  Mattru SL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mattru
# ------------------------
# Proceesing: City #  236  |  Shingu JP
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=shingu
# ------------------------
# Proceesing: City #  237  |  Havoysund NO
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=havoysund
# ------------------------
# Proceesing: City #  238  |  Ketchikan US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ketchikan
# ------------------------
# Proceesing: City #  239  |  Ngunguru NZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ngunguru
# ------------------------
# Proceesing: City #  240  |  Laukaa FI
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=laukaa
# ------------------------
# Proceesing: City #  241  |  Sao Joao dos Patos BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sao+joao+dos+patos
# ------------------------
# Proceesing: City #  242  |  Aswan EG
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=aswan
# ------------------------
# Proceesing: City #  243  |  Kirakira SB
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kirakira
# ------------------------
# Proceesing: City #  244  |  Sarakhs TM
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sarakhs
# ------------------------
# Proceesing: City #  245  |  San Patricio PY
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=san+patricio
# ------------------------
# Proceesing: City #  246  |  Cockburn Town TC
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=cockburn+town
# ------------------------
# Proceesing: City #  247  |  Caravelas BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=caravelas
# ------------------------
# Proceesing: City #  248  |  Kalabagh PK
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kalabagh
# ------------------------
# Proceesing: City #  249  |  Azare NG
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=azare
# ------------------------
# Proceesing: City #  250  |  Juruti BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=juruti
# ------------------------
# Proceesing: City #  251  |  Najran SA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=najran
# ------------------------
# Proceesing: City #  252  |  Half Moon Bay US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=half+moon+bay
# ------------------------
# Proceesing: City #  253  |  Belmonte PT
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=belmonte
# ------------------------
# Proceesing: City #  254  |  Mantua IT
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mantua
# ------------------------
# Proceesing: City #  255  |  Necochea AR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=necochea
# ------------------------
# Proceesing: City #  256  |  Hatillo PR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=hatillo
# ------------------------
# Proceesing: City #  257  |  Dwarka IN
# ...
# ------------------------
# Proceesing: City #  481  |  Parrita CR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=parrita
# ------------------------
# Proceesing: City #  482  |  Dhidhdhoo MV
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=dhidhdhoo
# City not found, skipping...
# ------------------------
# Proceesing: City #  483  |  Kungurtug RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kungurtug
# ------------------------
# Proceesing: City #  484  |  Buala SB
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=buala
# ------------------------
# Proceesing: City #  485  |  LOS ALGARROBOS EC
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=los+algarrobos
# City not found, skipping...
# ------------------------
# Proceesing: City #  486  |  Comodoro Rivadavia AR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=comodoro+rivadavia
# ------------------------
# Proceesing: City #  487  |  Mosquera CO
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mosquera
# ------------------------
# Proceesing: City #  488  |  Jambi ID
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=jambi
# ------------------------
# Proceesing: City #  489  |  Villa Corzo MX
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=villa+corzo
# ------------------------
# Proceesing: City #  490  |  Pangai TO
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=pangai
# ------------------------
# Proceesing: City #  491  |  Yenagoa NG
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=yenagoa
# ------------------------
# Proceesing: City #  492  |  Saint-Pierre FR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=saint-pierre
# ------------------------
# Proceesing: City #  493  |  Zhireken RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=zhireken
# ------------------------
# Proceesing: City #  494  |  Thunder Bay CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=thunder+bay
# ------------------------
# Proceesing: City #  495  |  Aksarka RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=aksarka
# ------------------------
# Proceesing: City #  496  |  Waynesville US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=waynesville
# ------------------------
# Proceesing: City #  497  |  Hutchinson US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=hutchinson
# ------------------------
# Proceesing: City #  498  |  Eyl SO
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=eyl
# ------------------------
# Proceesing: City #  499  |  Fort Nelson CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=fort+nelson
# ------------------------
# Proceesing: City #  500  |  Zeya RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=zeya
# ------------------------
# Proceesing: City #  501  |  Sisimiut GL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sisimiut
# ------------------------
# Proceesing: City #  502  |  Bitkine TD
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=bitkine
# ------------------------
# Proceesing: City #  503  |  Bontang ID
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=bontang
# ------------------------
# Proceesing: City #  504  |  Prince Rupert CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=prince+rupert
# ------------------------
# Proceesing: City #  505  |  Moron VE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=moron
# City not found, skipping...
# ------------------------
# Proceesing: City #  506  |  Wamba CD
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=wamba
# ------------------------
# Proceesing: City #  507  |  Avera US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=avera
# ------------------------
# Proceesing: City #  508  |  Dingle PH
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=dingle
# ------------------------
# Proceesing: City #  509  |  Geraldton CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=geraldton
# ------------------------
# Proceesing: City #  510  |  Kitab UZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kitob
# ------------------------
# Proceesing: City #  511  |  Paciran ID
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=paciran
# ------------------------
# Proceesing: City #  512  |  Ornskoldsvik SE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ornskoldsvik
# ------------------------
# Proceesing: City #  513  |  Buta CD
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=buta
# ------------------------
# Proceesing: City #  514  |  Pacifica US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=pacifica
# ------------------------
# Proceesing: City #  515  |  Maniitsoq GL
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=maniitsoq
# City not found, skipping...
# ------------------------
# Proceesing: City #  516  |  Biak ID
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=biak
# ------------------------
# Proceesing: City #  517  |  Sukumo JP
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=sukumo
# ------------------------
# Proceesing: City #  518  |  Honiara SB
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=honiara
# ------------------------
# Proceesing: City #  519  |  Mandalgovi MN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mandalgovi
# ------------------------
# Proceesing: City #  520  |  Bilibino RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=bilibino
# ------------------------
# Proceesing: City #  521  |  Wilmington US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=wilmington
# ------------------------
# Proceesing: City #  522  |  Quesnel CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=quesnel
# ------------------------
# Proceesing: City #  523  |  Nhulunbuy AU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=nhulunbuy
# ------------------------
# Proceesing: City #  524  |  Gazli UZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=gazli
# ------------------------
# Proceesing: City #  525  |  Kapuskasing CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kapuskasing
# ------------------------
# Proceesing: City #  526  |  Havelock US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=havelock
# ------------------------
# Proceesing: City #  527  |  Cukai MY
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=cukai
# ------------------------
# Proceesing: City #  528  |  Zabol IR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=zabol
# ------------------------
# Proceesing: City #  529  |  Chara GR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=chara
# ------------------------
# Proceesing: City #  530  |  Naryan-Mar RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=naryan-mar
# ------------------------
# Proceesing: City #  531  |  Hirado JP
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=hirado
# City not found, skipping...
# ------------------------
# Proceesing: City #  532  |  Rio Grande BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=rio+grande
# ------------------------
# Proceesing: City #  533  |  Salgueiro BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=salgueiro
# ------------------------
# Proceesing: City #  534  |  Dukat RS
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=dukat
# City not found, skipping...
# ------------------------
# Proceesing: City #  535  |  Doka SD
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=doka
# ------------------------
# Proceesing: City #  536  |  Ekhabi RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ekhabi
# ------------------------
# Proceesing: City #  537  |  Winnemucca US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=winnemucca
# ------------------------
# Proceesing: City #  538  |  Okha RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=okha
# ------------------------
# Proceesing: City #  539  |  Mbala ZM
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=mbala
# ------------------------
# Proceesing: City #  540  |  Banff CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=banff
# ------------------------
# Proceesing: City #  541  |  Hobyo SO
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=hobyo
# ------------------------
# Proceesing: City #  542  |  Znamenka RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=znamenka
# ------------------------
# Proceesing: City #  543  |  Shimoda JP
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=shimoda
# ------------------------
# Proceesing: City #  544  |  Barcelos PT
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=barcelos
# ------------------------
# Proceesing: City #  545  |  Maine-Soroa NE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=maine-soroa
# ------------------------
# Proceesing: City #  546  |  Axim GH
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=axim
# ------------------------
# Proceesing: City #  547  |  Altay CN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=altay
# ------------------------
# Proceesing: City #  548  |  Havre-Saint-Pierre CA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=havre-saint-pierre
# ------------------------
# Proceesing: City #  549  |  Grand-Santi GF
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=grand-santi
# ------------------------
# Proceesing: City #  550  |  Umm Lajj SA
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=umm+lajj
# ------------------------
# Proceesing: City #  551  |  Ust-Nera RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ust-nera
# ------------------------
# Proceesing: City #  552  |  Alcaniz ES
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=alcaniz
# ------------------------
# Proceesing: City #  553  |  Jega NG
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=jega
# ------------------------
# Proceesing: City #  554  |  Turukhansk RU
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=turukhansk
# ------------------------
# Proceesing: City #  555  |  Harnai PK
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=harnai
# ------------------------
# Proceesing: City #  556  |  Dayong PH
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=dayong
# ------------------------
# Proceesing: City #  557  |  Linxia CN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=linxia
# ------------------------
# Proceesing: City #  558  |  Matadi CD
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=matadi
# ------------------------
# Proceesing: City #  559  |  Nassau DE
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=nassau
# ------------------------
# Proceesing: City #  560  |  Alcazar de San Juan ES
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=alcazar+de+san+juan
# ------------------------
# Proceesing: City #  561  |  Pierre US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=pierre
# ------------------------
# Proceesing: City #  562  |  Ranong TH
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=ranong
# ------------------------
# Proceesing: City #  563  |  Bhatapara IN
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=bhatapara
# ------------------------
# Proceesing: City #  564  |  La Crosse US
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=la+crosse
# ------------------------
# Proceesing: City #  565  |  Urucara BR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=urucara
# ------------------------
# Proceesing: City #  566  |  Kuryk KZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=kuryk
# ------------------------
# Proceesing: City #  567  |  Waitati NZ
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=waitati
# City not found, skipping...
# ------------------------
# Proceesing: City #  568  |  Goma CD
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=goma
# ------------------------
# Proceesing: City #  569  |  Nouadhibou MR
# http://api.openweathermap.org/data/2.5/weather?appid=247a814903ee011da0db7fef0e8d69c3&units=IMPERIAL&q=nouadhibou

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
new_cities_df.to_csv("weather_data.csv", encoding="utf-8", index=False)

# %%
new_cities_df.head()
# Out:
#                City Country Temperature (F) Latitude Longitude Humidity (%)  \
# 0            Dikson      RU           11.04    73.51     80.55           93
# 1        Kaitangata      NZ              63   -46.28    169.85           66
# 3  Sao Luiz Gonzaga      BR            62.7   -28.41    -54.96           83
# 5          La Ronge      CA            55.4     55.1    -105.3           32
# 6             Kapaa      US           78.22    22.08   -159.32           65
#
#   Cloudiness (%) Wind Speed (mph)
# 0            100            31.83
# 1             35                3
# 3              0            10.31
# 5             75            12.75
# 6             40            11.41

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Build a scatter plot for Latitude vs. Temperature

plt.scatter(new_cities_df["Latitude"], 
            new_cities_df["Temperature (F)"], c=new_cities_df["Temperature (F)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='plasma', alpha=0.8, label="City")

plt.title(f"City Latitude vs. Max Temperature {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-60, 120])

# Save the figure
plt.savefig("Latitude_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Build a scatter plot for Latitude vs. Humidity (%)

plt.scatter(new_cities_df["Latitude"], 
            new_cities_df["Humidity (%)"], c=new_cities_df["Humidity (%)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='inferno', alpha=0.8, label="City")

# Graph Properties
plt.title(f"City Latitude vs. Humidity (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 125])

# Save the figure
plt.savefig("Latitude_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Build a scatter plot for Latitude vs. Cloudiness (%)

plt.scatter(new_cities_df["Latitude"], 
            new_cities_df["Cloudiness (%)"], c=new_cities_df["Cloudiness (%)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='bone_r', alpha=0.8, label="City")

#Graph Properties
plt.title(f"City Latitude vs. Cloudiness (%) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-10, 125])

# Save the figure
plt.savefig("Latitude_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Build a scatter plot for Latitude vs. Wind Speed (mph)

plt.scatter(new_cities_df["Latitude"], 
            new_cities_df["Wind Speed (mph)"], c=new_cities_df["Wind Speed (mph)"],
            edgecolor="black", linewidths=1, marker="o", 
            cmap='Spectral_r', alpha=0.8, label="City")

# Wind Properties
plt.title(f"City Latitude vs. Wind Speed (mph) {datetime.now().strftime('%m/%d/%Y')}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-10, 50])

# Save the figure
plt.savefig("Latitude_WindSpeed.png")

# Show plot
plt.show()
